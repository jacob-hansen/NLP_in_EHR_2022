# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Descriptions

# %%
names = pd.read_csv('../features_survey.csv')
names.head()
# Out:
#                               Heart Rate Variability  \
# 0  variance in time between heartbeats. measured ...
# 1  The amount of time between heart beats measure...
# 2  The standard deviation of all NN intervals wit...
# 3  The mean variance of the heart rate space, mea...
# 4  HRV is a measure of the variability in time be...
#
#                               CSF Tau Concentrations  \
# 0  Concentration of the Tau protein in cerebrospi...
# 1  Amount of Tau detected in CSF measured by pico...
# 2  The concentration of Tau Filament in the cereb...
# 3  Tau Filament is measured by taking a sample of...
# 4  A bio marker for neurological disorder such as...
#
#                 Unconsciousness Duration Upon Injury  \
# 0  How long a person is in an unresponsive state ...
# 1  how long a person is in an unresponsive state ...
# 2  How long the patient is unconscious upon impac...
# 3  Length of time that the patient was unconsciou...
# 4  Loss of consciousness for a given amount of ti...
#
#                                     Head Injury Type  \
# 0  a head injury can either be open, where a vict...
# 1  can range from external skull injury to intern...
# 2  The location where the head injury occurred. E...
# 3  The classification of the head injury based on...
# 4  Level of brain trauma or injury. Measured by d...
#
#                                    Time Since Injury  \
# 0  time that has elapsed since the impact to the ...
# 1  how long it has beensince the initial head imp...
# 2  The number of days that have elapsed since rec...
# 3  How long, in hours, that have passed since the...
# 4  The amount of time needed to recover from a co...
#
#                                  Arm Injury Severity  \
# 0  arm pain that ranges from manageable to severe...
# 1  combination of how impacted or deformed the ar...
# 2  A measure of how severe an arm injury is range...
# 3  A measurement of the arm injury severity. Scal...
# 4  Type of arm injury. Listed condition and severity
#
#                                        Acne Severity  \
# 0  can be classified by number of eruptions on th...
# 1  combination of type of acne (whiteheads, black...
# 2  A measure of the severity of the facial acne [...
# 3  How severe the patient's acne appears. 1-10 fo...
# 4  Acne Measured by grade 1-4. Count types of les...
#
#                Day to Day Happiness and Satisfaction  \
# 0  how happy and satisfied one is with their life...
# 1  how happy or satisfied someone is with their a...
# 2  A survey response for 10 questions on the pati...
# 3  A patient's indication 1-10 of their day to da...
# 4  Self reported on a scale 1-10. Questions about...
#
#                              Disability Rating Score  \
# 0  range of how much the disability affects quali...
# 1  how impactful the disability is on quality of ...
# 2  A survey of the disability rating from the car...
# 3  Indicator for prior disabilities that the pati...
# 4  DRS is a percentage of your disability. 0% is ...
#
#             Obesity Rating (How Obese is the Person)
# 0  how body fat is distributed and how much of so...
# 1  If your BMI is 18.5 to <25, it falls within th...
# 2  An obesity rating based on the BMI range of th...
# 3  An indicator for prior history in the medical ...
# 4  Body mass index (BMI) is a person's weight in ...

# %%
# Randomly shuffle each column of names
names = names.sample(frac=1).reset_index(drop=True)

# train on first 3 rows of patients
# test on the last row 
names_train = names.iloc[:3, :]
names_test = names.iloc[3:, :]

names_train.head()
# Out:
#                               Heart Rate Variability  \
# 0  variance in time between heartbeats. measured ...
# 1  The mean variance of the heart rate space, mea...
# 2  The standard deviation of all NN intervals wit...
#
#                               CSF Tau Concentrations  \
# 0  Concentration of the Tau protein in cerebrospi...
# 1  Tau Filament is measured by taking a sample of...
# 2  The concentration of Tau Filament in the cereb...
#
#                 Unconsciousness Duration Upon Injury  \
# 0  How long a person is in an unresponsive state ...
# 1  Length of time that the patient was unconsciou...
# 2  How long the patient is unconscious upon impac...
#
#                                     Head Injury Type  \
# 0  a head injury can either be open, where a vict...
# 1  The classification of the head injury based on...
# 2  The location where the head injury occurred. E...
#
#                                    Time Since Injury  \
# 0  time that has elapsed since the impact to the ...
# 1  How long, in hours, that have passed since the...
# 2  The number of days that have elapsed since rec...
#
#                                  Arm Injury Severity  \
# 0  arm pain that ranges from manageable to severe...
# 1  A measurement of the arm injury severity. Scal...
# 2  A measure of how severe an arm injury is range...
#
#                                        Acne Severity  \
# 0  can be classified by number of eruptions on th...
# 1  How severe the patient's acne appears. 1-10 fo...
# 2  A measure of the severity of the facial acne [...
#
#                Day to Day Happiness and Satisfaction  \
# 0  how happy and satisfied one is with their life...
# 1  A patient's indication 1-10 of their day to da...
# 2  A survey response for 10 questions on the pati...
#
#                              Disability Rating Score  \
# 0  range of how much the disability affects quali...
# 1  Indicator for prior disabilities that the pati...
# 2  A survey of the disability rating from the car...
#
#             Obesity Rating (How Obese is the Person)
# 0  how body fat is distributed and how much of so...
# 1  An indicator for prior history in the medical ...
# 2  An obesity rating based on the BMI range of th...

# %% [markdown]
# # Data Sampling and Label Generation

# %%
# simulate data by sampling 1000 patients 
n_train = 10000
n_test = 1000

# Each patient has 10 features
# with feature values ranging from 0 to 1
# and a feature description pulled from the survey

# create a covariance matrix for 10 features
# with 0.5 correlation between random features
cov = np.random.rand(10, 10)
# make sure it's symmetric
cov = (cov + cov.T) / 2
# make sure it's positive definite
cov[np.diag_indices_from(cov)] = 1
# make sure it's not too correlated
cov = 0.5 * cov

# create a dataframe with 1000 rows and 10 columns
# with values sampled from a multivariate normal distribution
# with mean 0 and covariance matrix cov
X_train = pd.DataFrame(np.random.multivariate_normal(np.zeros(10), cov, n_train))
X_test = pd.DataFrame(np.random.multivariate_normal(np.zeros(10), cov, n_test))
# Out:
# <ipython-input-5-b89d9371789d>:22: RuntimeWarning: covariance is not positive-semidefinite.
#   X_train = pd.DataFrame(np.random.multivariate_normal(np.zeros(10), cov, n_train))
# <ipython-input-5-b89d9371789d>:23: RuntimeWarning: covariance is not positive-semidefinite.
#   X_test = pd.DataFrame(np.random.multivariate_normal(np.zeros(10), cov, n_test))

# %%
# add a label column
# with values calculated from the first 3 features 
# by the equation y = 0.5 * x1 + 0.3 * x2 + 0.2 * x3
# and adding random noise
y_train = 0.5 * X_train.iloc[:, 0] + 0.3 * X_train.iloc[:, 1] + 0.2 * X_train.iloc[:, 2] + np.random.normal(0, 0.1, n_train)
y_test = 0.5 * X_test.iloc[:, 0] + 0.3 * X_test.iloc[:, 1] + 0.2 * X_test.iloc[:, 2] + np.random.normal(0, 0.1, n_test)

# use a threshold at the 80th percentile to create a binary label
y_train = (y_train > np.percentile(y_train, 50)).astype(int)
y_test = (y_test > np.percentile(y_test, 50)).astype(int)

# %% [markdown]
# # Testing Linear Regression to Learn Distribution (It Works Great!!)

# %%
# test linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# train model
model = LinearRegression()

# fit model on training data
model.fit(X_train, y_train)

# predict on test data
y_pred = model.predict(X_test)

# convert predictions to binary labels
y_pred = (y_pred > np.percentile(y_pred, 50)).astype(int)

# calculate f1 score
results = accuracy_score(y_test, y_pred)
print(f"Accuracy of linear regression is {results}")

# test training model on X_train with random shuffle of values
# as baseline comparison

# shuffle values in each column
X_train_shuffled = X_train.apply(np.random.permutation)

# train model
model = LinearRegression()

# fit model on training data
model.fit(X_train_shuffled, y_train)

# predict on test data
y_pred = model.predict(X_test)

# convert predictions to binary labels
y_pred = (y_pred > np.percentile(y_pred, 80)).astype(int)

# calculate accuracy
results = accuracy_score(y_test, y_pred)
print(f"Accuracy on random shuffle is {results}")
# Out:
# Accuracy of linear regression is 0.948
# Accuracy on random shuffle is 0.642

# %% [markdown]
# # Feature Concatenation

# %%
# add feature descriptions for each patient by:
# 1. sampling 10 random feature descriptions from the survey in names_train
# 2. replace the values in X_train with the sampled feature descriptions 
#       concatenated with the values in X_train rounded to 3 decimal places
for i in range(len(names_train.columns)):
    # apply function to each element individually
    # using feature name np.random.choice(names_train.iloc[:,i], 1)
    X_train.iloc[:, i] = X_train.iloc[:, i].apply(lambda x: "Feature is " + np.random.choice(names_train.iloc[:,i], 1)[0] + '. VAL is ' + str(round(x, 3)) + ". ")
    
# do the same for X_test
for i in range(len(names_test.columns)):
    X_test.iloc[:, i] = X_test.iloc[:, i].apply(lambda x: "Feature is " + np.random.choice(names_test.iloc[:,i], 1)[0] + '. VAL is ' + str(round(x, 3)) + ". ")

X_train.head()
# Out:
#                                                    0  \
# 0  Feature is The standard deviation of all NN in...
# 1  Feature is variance in time between heartbeats...
# 2  Feature is The standard deviation of all NN in...
# 3  Feature is variance in time between heartbeats...
# 4  Feature is The mean variance of the heart rate...
#
#                                                    1  \
# 0  Feature is Tau Filament is measured by taking ...
# 1  Feature is The concentration of Tau Filament i...
# 2  Feature is Concentration of the Tau protein in...
# 3  Feature is Tau Filament is measured by taking ...
# 4  Feature is Tau Filament is measured by taking ...
#
#                                                    2  \
# 0  Feature is Length of time that the patient was...
# 1  Feature is How long the patient is unconscious...
# 2  Feature is How long the patient is unconscious...
# 3  Feature is How long the patient is unconscious...
# 4  Feature is Length of time that the patient was...
#
#                                                    3  \
# 0  Feature is The classification of the head inju...
# 1  Feature is The classification of the head inju...
# 2  Feature is The location where the head injury ...
# 3  Feature is The classification of the head inju...
# 4  Feature is The classification of the head inju...
#
#                                                    4  \
# 0  Feature is The number of days that have elapse...
# 1  Feature is How long, in hours, that have passe...
# 2  Feature is How long, in hours, that have passe...
# 3  Feature is How long, in hours, that have passe...
# 4  Feature is The number of days that have elapse...
#
#                                                    5  \
# 0  Feature is A measurement of the arm injury sev...
# 1  Feature is A measurement of the arm injury sev...
# 2  Feature is A measurement of the arm injury sev...
# 3  Feature is A measure of how severe an arm inju...
# 4  Feature is A measure of how severe an arm inju...
#
#                                                    6  \
# 0  Feature is can be classified by number of erup...
# 1  Feature is How severe the patient's acne appea...
# 2  Feature is How severe the patient's acne appea...
# 3  Feature is can be classified by number of erup...
# 4  Feature is A measure of the severity of the fa...
#
#                                                    7  \
# 0  Feature is A survey response for 10 questions ...
# 1  Feature is A survey response for 10 questions ...
# 2  Feature is how happy and satisfied one is with...
# 3  Feature is how happy and satisfied one is with...
# 4  Feature is how happy and satisfied one is with...
#
#                                                    8  \
# 0  Feature is range of how much the disability af...
# 1  Feature is A survey of the disability rating f...
# 2  Feature is Indicator for prior disabilities th...
# 3  Feature is Indicator for prior disabilities th...
# 4  Feature is Indicator for prior disabilities th...
#
#                                                    9
# 0  Feature is An obesity rating based on the BMI ...
# 1  Feature is An indicator for prior history in t...
# 2  Feature is how body fat is distributed and how...
# 3  Feature is An obesity rating based on the BMI ...
# 4  Feature is how body fat is distributed and how...

# %% [markdown]
# # RNN Dataset Creation

# %%
# for each patient, concatenate all the features in a random order 
# to create a single string
X_train = X_train.apply(lambda x: ' '.join(x.sample(frac=1)), axis=1)
X_test = X_test.apply(lambda x: ' '.join(x.sample(frac=1)), axis=1)

X_train.head()
# Out:
# 0    Feature is A survey response for 10 questions ...
# 1    Feature is variance in time between heartbeats...
# 2    Feature is how happy and satisfied one is with...
# 3    Feature is Tau Filament is measured by taking ...
# 4    Feature is Length of time that the patient was...
# dtype: object

# %%
X_train.iloc[0]
# Out:
# "Feature is A survey response for 10 questions on the patient's overall happiness and satisfaction in work and personal life. Responses were recorded between 1-6, with 1 being little satisfaction and extreme unhappiness, and 6 being well satisfied and happy.. VAL is -0.079.  Feature is Tau Filament is measured by taking a sample of the CSF within 24 hours of admitting using a BioGen Tau Assay.. VAL is 0.367.  Feature is An obesity rating based on the BMI range of the patient. Also weights in past prescriptions for obesity and progress current management strategies. . VAL is 0.223.  Feature is A measurement of the arm injury severity. Scaling with the expected time of recovery for the arm injury.. VAL is -0.279.  Feature is The standard deviation of all NN intervals within a 5 minute period taken using an electrocardiogram (EKG). Units in ms.. VAL is 0.808.  Feature is The classification of the head injury based on the location. 0 for hard skull, 1 for soft skull, 2 for critical areas (such as the temple).. VAL is 0.594.  Feature is can be classified by number of eruptions on the skin. the more eruptions, the more severe. can also be classified by the type of acne, which ranges from inflammatory lesions to inflamatory lesions to nodules and scarring. measured by count and type of eruption.. VAL is -0.173.  Feature is range of how much the disability affects quality of life. measured on a scale from 1-10 where 1 is minimal effect and 10 is highest level of effect on quality of life and shortens life expectancy. VAL is -0.136.  Feature is The number of days that have elapsed since receiving the injury. . VAL is -0.781.  Feature is Length of time that the patient was unconscious following the injury. If the patient was never unconscious, this is counted as 0 minutes. Time recorded in minutes.. VAL is 0.918. "

# %%
# find the maximum length of any string in names_train
# of names_train columns
max_length = max([len(x) for x in names_train.iloc[:, 0]])

# %%
max_length
# Out:
# 120

# %%
# combine X's and y's into a single dataframes
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)
# save data to csv as test_even.csv and train_even.csv
train.to_csv('train_even.csv', index=False)
test.to_csv('test_even.csv', index=False)
